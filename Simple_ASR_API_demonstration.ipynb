# %% [markdown]
# <a href="https://colab.research.google.com/github/xuanxixi/Learnable-PCEN-frontend-in-pytorch/blob/main/Simple_ASR_API_demonstration.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Let's demonstrate how to do automatic speech recognition (ASR), without understanding anything about 'speech' or 'recognition'. This is totally fine, of course, if your interest is to simply apply ASR in your research or business.
#
# This is a university course, however! 😉 In the remainder of the course, we'll be digging more into details to understand how speech technology (including ASR) works.

# %%
# Install necessary libraries
# !pip install SpeechRecognition

# Import libraries
import speech_recognition as sr
import io
from IPython.display import Audio, display
from google.colab import files
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 32.8/32.8 MB 7.3 MB/s eta 0:00:00
# ...

# %%
# Upload an audio file
uploaded = files.upload()

# Load the audio file
file_name = next(iter(uploaded))  # Get the uploaded file name
display(Audio(file_name, autoplay=True))

# Initialize speech recognizer
recognizer = sr.Recognizer()

# Convert AudioFile to AudioData
with sr.AudioFile(file_name) as source:
    audio_data = recognizer.record(source)

# Recognize the speech using Google's Web Speech API
try:
    text = recognizer.recognize_google(audio_data)
    print("Transcription: " + text)
except sr.UnknownValueError:
    print("Google Speech Recognition could not understand audio")
except sr.RequestError as e:
    print(f"Could not request results from Google Speech Recognition service; {e}")
# Out:
#      <input type="file" id="files-32dd4665-ec94-4249-8c13-c0bff1d0695f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-32dd4665-ec94-4249-8c13-c0bff1d0695f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...
